# %% [markdown]
# <a href="https://colab.research.google.com/github/Fush1m1/colab_copies/blob/main/jQuants.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import json

token = "eyJraWQiOiJOY3prOTNVY1hqYmtEN2NHQWFYN0NMaXZWTytGRkxhejQ0cUJLc0FFK3o4PSIsImFsZyI6IlJTMjU2In0.....Tq10Bc48m7K31ksTf35RosXaVUM4L32xoMIZoQkVPKkofsZ-1tPgsYES0y-GwsBu2u22FmJKVsbg7Q1JB40_U4luIVwwm7RhYdTuLyWvwJ2z3cUQq1NLEBqKm1-z8fbBNY9a6p-NUumn0HPDXzUdOI8MbsaEVv48iL9wnuEM1gElDvR2N-AJaEubsFdng5gfkLWF6RSOqW8xOSJ_8WSp6MtjwfdUZKDV2TL3cb383fLtaQoNsME7KOiwrZlyF_Zf99q18JYAa9vuBIETr9UuksvubTqw2MwYuQ5Lt1uvygBbw3UVlWLSBMV0ipLr-tz910RIwfqBBzhclGa2slxu6w"
headers = {'Authorization': 'Bearer {}'.format(token)}
r = requests.get("https://api.jpx-jquants.com/v1/listed/info", headers=headers)
r.json()
# Out:
# {'info': [{'Code': '79860',
#    'CompanyName': '日本アイエスケイ',
#    'CompanyNameEnglish': 'NIHON ISK Company,Limited',
#    'CompanyNameFull': '日本アイ・エス・ケイ',
#    'MarketCode': 'B',
#    'SectorCode': '3800',
#    'UpdateDate': '20220415'},
#   {'Code': '33280',
#    'CompanyName': 'ＢＥＥＮＯＳ',
#    'CompanyNameEnglish': 'BEENOS Inc.',
#    'CompanyNameFull': 'ＢＥＥＮＯＳ',
#    'MarketCode': 'A',
#    'SectorCode': '6100',
#    'UpdateDate': '20220415'},
#   {'Code': '31970',
#    'CompanyName': 'すかいらーくＨＤ',
#    'CompanyNameEnglish': 'SKYLARK HOLDINGS CO.,LTD.',
#    'CompanyNameFull': '（株）すかいらーくホールディングス',
#    'MarketCode': 'A',
#    'SectorCode': '6100',
#    'UpdateDate': '20220415'},
#   {'Code': '72410',
#    'CompanyName': 'フタバ産',
#    'CompanyNameEnglish': 'FUTABA INDUSTRIAL CO.,LTD.',
#    'CompanyNameFull': 'フタバ産業',
#    'MarketCode': 'A',
#    'SectorCode': '3700',
#    'UpdateDate': '20220415'},
#   {'Code': '83030',
#    'CompanyName': '新生銀',
# ...
